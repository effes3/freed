# %%
# %cd mols
# Out:
# /home/semakin_grisha/FFREED/experiments/freed_expert_v1/mols

# %%
import pandas as pd
df = pd.read_csv('train_000.csv')

# %%
df['Smiles'][len(df)-1]
# Out:
# 'Ic1ccc(C2CCCCC2OCNCCc2cccs2)cc1'

# %%
df
# Out:
#                                                   Smiles DockingScoreReward  \
# 0      CC1CCN(C(=O)c2ccc(C3OCCC3C(=O)Nc3cccc(C(F)(F)F...                2.5
# 1      COC1(c2ccc(S(C)(=O)=O)cc2)CC(N[N-]C2CC(=O)N(C(...                2.4
# 2      COc1ccc(Cn2cnnc2CNc2cccc(OCCF)c2)c(Oc2ccc(N(C=...               -0.0
# 3       CC=NNSC(C)C(=O)Nc1ccc(C(=O)OCCCC2COCC[NH2+]2)cc1                3.3
# 4            CCCC(Nc1cccc(OC)c1CC(C=O)NC=O)c1ccc(COC)cc1                2.9
# ...                                                  ...                ...
# 14188  CC(NS(=O)(=O)C(C)c1occc1C1CCCC1O)c1ccc(N(C)C(C...                3.7
# 14189  O=C(c1ccc(NC(=S)CN2CC[NH+](CN3C(=O)C4CC=CCC4C3...                2.7
# 14190   N#CCCSC(COC1CCCCC1c1ccc(C2CCCCC2CO)cc1)C(=O)[O-]               -0.0
# 14191  CCC(N)C(=O)CN(Cc1ccc(CC2COCC[NH2+]2)cc1)C(=O)C...                2.5
# 14192                    Ic1ccc(C2CCCCC2OCNCCc2cccs2)cc1                2.3
#
#       Reward DockingScoreProperty Epoch
# ...
